# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("train.csv")

# %%
data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
data.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
# Frequency Distibution Check 
countinious_column = data.iloc[:,:-1]
for col in countinious_column:
    sns.histplot(data[col], kde = True, bins = 7)
    plt.title(f"Frequency Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
# data visualizing the whole from histogram
data.hist(bins = 10, figsize = (30, 30), color = "green")
plt.show()

# %%
# Bar plot for Categorical Columns 
sns.countplot(x = "price_range", data = data)
plt.title("Distribution Of price Range")
plt.xlabel("Price Range")
plt.ylabel("Count")
plt.show()

# %%
# Box plot to compare continious variables
for coln in countinious_column:
    sns.boxplot(x = "price_range", y = coln, data = data)
    plt.title(f"{coln} by Price Range")
    plt.show()

# %%
# Violin Plot for Check distribution Of Price Range
for var in countinious_column:
    sns.violinplot(x = "price_range", y = var, data = data)
    plt.title(f"{var} Distribution of Price Range")
    plt.show()

# %%
# HeatMap for Correlation
correlation = data.corr()
plt.figure(figsize = (30, 30))
sns.heatmap(correlation, annot = True, annot_kws = {"size" : 12})
plt.title("Correlation heatmap")
plt.tick_params(labelsize = 12)
plt.show()

# %%
# Relationship Between Independent  And Target Variable
for col in countinious_column:
    sns.scatterplot(x = data[col], y = data["price_range"])
    plt.title(f"Relationship Between {col} and Price Range")
    plt.xlabel(col)
    plt.ylabel("Price Range")
    plt.show()

# %% [markdown]
# # load Tools

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
x = data.iloc[:,:-1]
y = data["price_range"]

# %%
# splitting data into Training and Testing Part

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
# scalling X_train and X_test
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
# fitting data to model
model = LogisticRegression(random_state = 42)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
# Comparing Actual and Predicted Value and Bias 
y_pred = model.predict(X_test)
evaluation = pd.DataFrame({
    "Actual Value" : y_test,
    "Predicted Value" : y_pred,
    "Error" : y_test - y_pred
})
evaluation
# Out:
#       Actual Value  Predicted Value  Error
# 1860             0                0      0
# 353              2                2      0
# 1333             1                1      0
# 905              3                3      0
# 1289             1                1      0
# ...            ...              ...    ...
# 965              3                3      0
# 1284             2                2      0
# 1739             1                1      0
# 261              1                1      0
# 535              2                2      0
#
# [400 rows x 3 columns]

# %%
# Checking Accuracy and Confusion metrix
accuracy = accuracy_score(y_test, y_pred) * 100
confusion_m = confusion_matrix(y_test, y_pred)
print(f"Model Accuracy is {accuracy}")
# Out:
# Model Accuracy is 95.0

# %%
sns.heatmap(confusion_m, annot = True, fmt = "d", color = "blue")
plt.title("Confusion Metrix By heatmap ")
plt.show()
